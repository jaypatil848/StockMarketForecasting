# %% [markdown]
# ### Libraries

# %%
# pip install yfinance

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')


# Libraries for Data extraction 
from datetime import datetime
import yfinance as yf


#Visualization Libraries
import matplotlib.pyplot as plt
import seaborn as sns

#Warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Data Extraction

# %% [markdown]
# Objective is to get the data of RELIANCE INDUSTRIES from 01/01/2015 to till date.
#
# Columns required are Open,High,Low,Close

# %%
# Defining Parameters
start_date = datetime(2015,1,1)
end_date = datetime.today()

#Data downloading
data = yf.download('RELIANCE.NS',start=start_date,end=end_date)
data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2015-01-01   438.988831   441.812073   437.676270   439.781311   417.988922
# 2015-01-02   439.880371   443.818054   437.998199   438.617340   416.882629
# 2015-01-05   438.344940   441.267212   432.946106   433.812897   412.316223
# 2015-01-06   430.915344   432.401276   412.093750   414.124512   393.603516
# 2015-01-07   414.619812   425.367950   414.570282   423.139069   402.171295
# ...                 ...          ...          ...          ...          ...
# 2023-01-30  2331.699951  2371.899902  2301.000000  2359.750000  2359.750000
# 2023-01-31  2382.000000  2387.649902  2341.000000  2353.850098  2353.850098
# 2023-02-01  2379.949951  2379.949951  2305.000000  2339.899902  2339.899902
# 2023-02-02  2318.000000  2348.000000  2311.000000  2326.949951  2326.949951
# 2023-02-03  2349.000000  2349.000000  2293.000000  2322.050049  2322.050049
#
#               Volume
# Date
# 2015-01-01   1367720
# 2015-01-02   3383424
# 2015-01-05   4662967
# 2015-01-06   8596809
# 2015-01-07   9562421
# ...              ...
# 2023-01-30  10047822
# 2023-01-31  10472167
# 2023-02-01   8929007
# 2023-02-02   6305317
# 2023-02-03   6301756
#
# [2000 rows x 6 columns]

# %%
data.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2015-01-01  438.988831  441.812073  437.676270  439.781311  417.988922
# 2015-01-02  439.880371  443.818054  437.998199  438.617340  416.882629
# 2015-01-05  438.344940  441.267212  432.946106  433.812897  412.316223
# 2015-01-06  430.915344  432.401276  412.093750  414.124512  393.603516
# 2015-01-07  414.619812  425.367950  414.570282  423.139069  402.171295
#
#              Volume
# Date
# 2015-01-01  1367720
# 2015-01-02  3383424
# 2015-01-05  4662967
# 2015-01-06  8596809
# 2015-01-07  9562421

# %%
data.tail()
# Out:
#                    Open         High     Low        Close    Adj Close  \
# Date
# 2023-01-30  2331.699951  2371.899902  2301.0  2359.750000  2359.750000
# 2023-01-31  2382.000000  2387.649902  2341.0  2353.850098  2353.850098
# 2023-02-01  2379.949951  2379.949951  2305.0  2339.899902  2339.899902
# 2023-02-02  2318.000000  2348.000000  2311.0  2326.949951  2326.949951
# 2023-02-03  2349.000000  2349.000000  2293.0  2322.050049  2322.050049
#
#               Volume
# Date
# 2023-01-30  10047822
# 2023-01-31  10472167
# 2023-02-01   8929007
# 2023-02-02   6305317
# 2023-02-03   6301756

# %%
data.drop({'Adj Close','Volume','Open','High','Low'},axis=1,inplace = True)
data
# Out:
#                   Close
# Date
# 2015-01-01   439.781311
# 2015-01-02   438.617340
# 2015-01-05   433.812897
# 2015-01-06   414.124512
# 2015-01-07   423.139069
# ...                 ...
# 2023-01-30  2359.750000
# 2023-01-31  2353.850098
# 2023-02-01  2339.899902
# 2023-02-02  2326.949951
# 2023-02-03  2322.050049
#
# [2000 rows x 1 columns]

# %% [markdown]
# ### EDA

# %%
data.head()
# Out:
#                  Close
# Date
# 2015-01-01  439.781311
# 2015-01-02  438.617340
# 2015-01-05  433.812897
# 2015-01-06  414.124512
# 2015-01-07  423.139069

# %%
data.tail()
# Out:
#                   Close
# Date
# 2023-01-30  2359.750000
# 2023-01-31  2353.850098
# 2023-02-01  2339.899902
# 2023-02-02  2326.949951
# 2023-02-03  2322.050049

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2000 entries, 2015-01-01 to 2023-02-03
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   2000 non-null   float64
# dtypes: float64(1)
# memory usage: 31.2 KB

# %%
data.isna().sum()
# Out:
# Close    0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 58

# %%
data.describe()
# Out:
#              Close
# count  2000.000000
# mean   1328.562782
# std     757.363940
# min     401.568542
# 25%     533.294907
# 50%    1188.434875
# 75%    2068.574951
# max    2819.850098

# %% [markdown]
# Correlation matrix shows that data is highly correlated.

# %%
#Distplots to check the distribution of data

plt.figure(figsize=(17,15))
plt.subplot(4,1,4)
sns.distplot(data['Close'])
plt.title("Reliance stock Close Prices")
# Out:
# Text(0.5, 1.0, 'Reliance stock Close Prices')

# %% [markdown]
# #### To check normality of the data
# Shapiro test(p-value > 0.05 -- Normally distributed data)

# %%
from scipy import stats

shapiro_test = stats.shapiro(data)
print('stats= ', shapiro_test.statistic,'\npvalue = ',shapiro_test.pvalue)
# Out:
# stats=  0.8921695947647095
# pvalue =  2.751882784797862e-35

# %%
# QQ Plot

import statsmodels.api as sm

sm.qqplot(data['Close'], line='q')
plt.title('Close')
# Out:
# Text(0.5, 1.0, 'Close')

# %%
plt.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x23de99d5310>,
#   <matplotlib.lines.Line2D at 0x23de99d55e0>],
#  'caps': [<matplotlib.lines.Line2D at 0x23de99d58b0>,
#   <matplotlib.lines.Line2D at 0x23de99d5b80>],
#  'boxes': [<matplotlib.lines.Line2D at 0x23de99d5040>],
#  'medians': [<matplotlib.lines.Line2D at 0x23de99d5e50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x23de99e5160>],
#  'means': []}

# %% [markdown]
# Since pvalue < 0.05 & from the QQ plot, we can infer that data is not normally distributed

# %% [markdown]
# Hence to make data normally distributed we need to do minmaxscaling to the data.

# %%
# from sklearn.preprocessing import MinMaxScaler
# minmax = MinMaxScaler()

# data1 = pd.DataFrame()
# data1[data.columns] = minmax.fit_transform(data)
# data1

# %%
data.skew()
#Allowable range is from -2 to +2
# Out:
# Close    0.411801
# dtype: float64

# %%
data.kurt()
#Allowable range is from -7 to +7
# Out:
# Close   -1.263471
# dtype: float64

# %% [markdown]
# ## Visualization

# %% [markdown]
# https://colab.research.google.com/drive/1M9oLQgGiBubg6LK3XSraJoSyniNMht3_#scrollTo=bxuyYmJVTaUT

# %% [markdown]
# ## Model Building

# %%
data
# Out:
#                   Close
# Date
# 2015-01-01   439.781311
# 2015-01-02   438.617340
# 2015-01-05   433.812897
# 2015-01-06   414.124512
# 2015-01-07   423.139069
# ...                 ...
# 2023-01-30  2359.750000
# 2023-01-31  2353.850098
# 2023-02-01  2339.899902
# 2023-02-02  2326.949951
# 2023-02-03  2322.050049
#
# [2000 rows x 1 columns]

# %%
data['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## Rolling Mean & Rolling Standard deviation

# %%
from statsmodels.tsa.stattools import adfuller
def test_stationarity(timeseries):
    #Determing rolling statistics
    rolmean = timeseries.rolling(12).mean()
    rolstd = timeseries.rolling(12).std()
    #Plot rolling statistics:
    plt.plot(timeseries, color='yellow',label='Original')
    plt.plot(rolmean, color='red', label='Rolling Mean')
    plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean and Standard Deviation')
    plt.show(block=False)
    print("Results of AD-fuller test")
    adft = adfuller(timeseries,autolag='AIC')
    # output for dft will give us without defining what the values are.
    #hence we manually write what values does it explains using a for loop
    output = pd.Series(adft[0:4],index=['Test Statistics','p-value','No. of lags used','Number of observations used'])
    for key,values in adft[4].items():
        output['critical value (%s)'%key] =  values
    print(output)

test_stationarity(data)
# Out:
# Results of AD-fuller test
# Test Statistics                  -0.714990
# p-value                           0.842828
# No. of lags used                  5.000000
# Number of observations used    1994.000000
# critical value (1%)              -3.433634
# critical value (5%)              -2.862991
# critical value (10%)             -2.567542
# dtype: float64

# %%
#Ho: It is non stationary
#H1: It is stationary

def adfuller_test(sales):
    result=adfuller(sales)
    labels = ['ADF Test Statistic','p-value','#Lags Used','Number of Observations Used']
    for value,label in zip(result,labels):
        print(label+' : '+str(value) )
    if result[1] <= 0.05:
        print("strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data has no unit root and is stationary")
    else:
        print("weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary ")

# %% [markdown]
# ## Seasonal Decompositions

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
result = seasonal_decompose(data, model='multiplicative',period = 30)
fig = plt.figure()  
fig = result.plot()  
fig.set_size_inches(16, 9)

# %% [markdown]
# For time series analysis we separate Trend and Seasonality from the time series.

# %% [markdown]
# ## Logarithmic model

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 10, 6
df_log = np.log(data)
moving_avg = df_log.rolling(12).mean()
std_dev = df_log.rolling(12).std()
plt.legend(loc='best')
plt.title('Moving Average')
plt.plot(std_dev, color ="black", label = "Standard Deviation")
plt.plot(moving_avg, color="red", label = "Mean")
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## Train & Test Split

# %%
train=data[(data['Close'].index.get_level_values(0)>='2015-01-01')&(data['Close'].index.get_level_values(0)<='2020-01-01')]
test=data[(data['Close'].index.get_level_values(0)>'2020-01-01')]
plt.figure(figsize=(10,6))
plt.grid(True)
plt.xlabel('Dates')
plt.ylabel('Closing Prices')
plt.plot(train, 'green', label='Train data')
plt.plot(test, 'blue', label='Test data')
plt.legend()

# %%
train
# Out:
#                   Close
# Date
# 2015-01-01   439.781311
# 2015-01-02   438.617340
# 2015-01-05   433.812897
# 2015-01-06   414.124512
# 2015-01-07   423.139069
# ...                 ...
# 2019-12-26  1501.170410
# 2019-12-27  1527.867310
# 2019-12-30  1529.699951
# 2019-12-31  1499.833130
# 2020-01-01  1495.424927
#
# [1230 rows x 1 columns]

# %%
test.shape
# Out:
# (770, 1)

# %% [markdown]
# ## Shift Model

# %%
data['Close First Difference'] = data['Close'] - data['Close'].shift(12)

# %%
data['Close'].shift(12)
# Out:
# Date
# 2015-01-01            NaN
# 2015-01-02            NaN
# 2015-01-05            NaN
# 2015-01-06            NaN
# 2015-01-07            NaN
#                  ...
# 2023-01-30    2526.149902
# 2023-01-31    2471.600098
# 2023-02-01    2467.600098
# 2023-02-02    2444.100098
# 2023-02-03    2478.800049
# Name: Close, Length: 2000, dtype: float64

# %%
data.head(14)
# Out:
#                  Close  Close First Difference
# Date
# 2015-01-01  439.781311                     NaN
# 2015-01-02  438.617340                     NaN
# 2015-01-05  433.812897                     NaN
# 2015-01-06  414.124512                     NaN
# 2015-01-07  423.139069                     NaN
# 2015-01-08  417.071564                     NaN
# 2015-01-09  426.110901                     NaN
# 2015-01-12  421.157837                     NaN
# 2015-01-13  417.616425                     NaN
# 2015-01-14  413.554901                     NaN
# 2015-01-15  428.067352                     NaN
# 2015-01-16  430.766754                     NaN
# 2015-01-19  435.695038               -4.086273
# 2015-01-20  447.285187                8.667847

# %%
## Again test dickey fuller test
adfuller_test(data['Close First Difference'].dropna())
# Out:
# ADF Test Statistic : -7.416950710453538
# p-value : 6.895323277101711e-11
# #Lags Used : 26
# Number of Observations Used : 1961
# strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data has no unit root and is stationary

# %% [markdown]
# ##  ARIMA Model

# %%
# # For non-seasonal data
# #p=1, d=1, q=0 or 1
from statsmodels.tsa.arima.model import ARIMA

# %%
model=ARIMA(data['Close'],order=(1,1,1))
model_fit=model.fit()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\DELL\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\DELL\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
model_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                 2000
# Model:                 ARIMA(1, 1, 1)   Log Likelihood               -9436.051
# Date:                Fri, 03 Feb 2023   AIC                          18878.103
# Time:                        12:22:55   BIC                          18894.904
# Sample:                             0   HQIC                         18884.272
#                                - 2000
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.4993      2.126     -0.235      0.814      -4.667       3.668
# ma.L1          0.5036      2.119      0.238      0.812      -3.649       4.656
# sigma2       737.8800     11.168     66.072      0.000     715.991     759.768
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.60   Jarque-Bera (JB):              4033.25
# Prob(Q):                              0.44   Prob(JB):                         0.00
# Heteroskedasticity (H):              22.03   Skew:                             0.03
# Prob(H) (two-sided):                  0.00   Kurtosis:                         9.96
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
data['forecast']=model_fit.predict(start=1620,end=1980,dynamic=True)
data[['Close','forecast']].plot(figsize=(18,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## SARIMAX Model

# %%
model=sm.tsa.statespace.SARIMAX(data['Close'],order=(1, 1, 1),seasonal_order=(1,1,1,12))
results=model.fit()
data['forecast']=results.predict(start=1620,end=1980,dynamic=True)
data[['Close','forecast']].plot(figsize=(12,8))
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\DELL\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# <AxesSubplot:xlabel='Date'>

# %%
results.save("Sarimax.pkl")

# %%
from pandas.tseries.offsets import DateOffset
future_dates=[data.index[-1]+ DateOffset(days=x)for x in range(0,21)]
future_datest_df=pd.DataFrame(index=future_dates[1:],columns=data.columns)

future_datest_df.tail()

future_df=pd.concat([data,future_datest_df])

future_df['forecast'] = results.predict(start = 1620, end = 1985, typ='levels')
future_df[['Close', 'forecast']].plot(figsize=(12, 8))
# Out:
# <AxesSubplot:>

# %%
predictions=results.predict(start=1988,end=2018,typ='levels')
predictions.shape
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# (31,)

# %%
from datetime import timedelta, date
Date_req = date.today() + timedelta(days=31)
# Date_req

index_future_dates=pd.date_range(start=datetime.today(),end=Date_req)
a = len(data)
predictions.index=index_future_dates
print(predictions)
# Out:
# 2023-02-03 12:22:58.714767    2478.870490
# 2023-02-04 12:22:58.714767    2478.787412
# 2023-02-05 12:22:58.714767    2471.775756
# 2023-02-06 12:22:58.714767    2444.288081
# 2023-02-07 12:22:58.714767    2430.775785
# 2023-02-08 12:22:58.714767    2416.629238
# 2023-02-09 12:22:58.714767    2382.077060
# 2023-02-10 12:22:58.714767    2333.347180
# 2023-02-11 12:22:58.714767    2358.896912
# 2023-02-12 12:22:58.714767    2355.915393
# 2023-02-13 12:22:58.714767    2340.459097
# 2023-02-14 12:22:58.714767    2330.794688
# 2023-02-15 12:22:58.714767    2320.816571
# 2023-02-16 12:22:58.714767    2324.976714
# 2023-02-17 12:22:58.714767    2324.772746
# 2023-02-18 12:22:58.714767    2326.980193
# 2023-02-19 12:22:58.714767    2327.445422
# 2023-02-20 12:22:58.714767    2327.400180
# 2023-02-21 12:22:58.714767    2327.486661
# 2023-02-22 12:22:58.714767    2325.439246
# 2023-02-23 12:22:58.714767    2324.609555
# 2023-02-24 12:22:58.714767    2326.526774
# 2023-02-25 12:22:58.714767    2327.510073
# 2023-02-26 12:22:58.714767    2331.291034
# 2023-02-27 12:22:58.714767    2330.363928
# 2023-02-28 12:22:58.714767    2334.638614
# 2023-03-01 12:22:58.714767    2334.740162
# 2023-03-02 12:22:58.714767    2337.097485
# 2023-03-03 12:22:58.714767    2337.714232
# 2023-03-04 12:22:58.714767    2338.009710
# 2023-03-05 12:22:58.714767    2338.558757
# Freq: D, Name: predicted_mean, dtype: float64

# %%
predictions.to_csv("Predictions.csv")

# %%
new_pred = pd.concat([data,predictions], axis=1)
new_pred
# Out:
#                                  Close  Close First Difference  forecast  \
# 2015-01-01 00:00:00.000000  439.781311                     NaN       NaN
# 2015-01-02 00:00:00.000000  438.617340                     NaN       NaN
# 2015-01-05 00:00:00.000000  433.812897                     NaN       NaN
# 2015-01-06 00:00:00.000000  414.124512                     NaN       NaN
# 2015-01-07 00:00:00.000000  423.139069                     NaN       NaN
# ...                                ...                     ...       ...
# 2023-03-01 12:22:58.714767         NaN                     NaN       NaN
# 2023-03-02 12:22:58.714767         NaN                     NaN       NaN
# 2023-03-03 12:22:58.714767         NaN                     NaN       NaN
# 2023-03-04 12:22:58.714767         NaN                     NaN       NaN
# 2023-03-05 12:22:58.714767         NaN                     NaN       NaN
#
#                             predicted_mean
# 2015-01-01 00:00:00.000000             NaN
# 2015-01-02 00:00:00.000000             NaN
# 2015-01-05 00:00:00.000000             NaN
# 2015-01-06 00:00:00.000000             NaN
# 2015-01-07 00:00:00.000000             NaN
# ...                                    ...
# 2023-03-01 12:22:58.714767     2334.740162
# 2023-03-02 12:22:58.714767     2337.097485
# 2023-03-03 12:22:58.714767     2337.714232
# 2023-03-04 12:22:58.714767     2338.009710
# 2023-03-05 12:22:58.714767     2338.558757
#
# [2031 rows x 4 columns]

# %%
from datetime import datetime
d = new_pred.index
new_pred.index = d.strftime('%Y-%m-%d')

# %%
new_pred
# Out:
#                  Close  Close First Difference  forecast  predicted_mean
# 2015-01-01  439.781311                     NaN       NaN             NaN
# 2015-01-02  438.617340                     NaN       NaN             NaN
# 2015-01-05  433.812897                     NaN       NaN             NaN
# 2015-01-06  414.124512                     NaN       NaN             NaN
# 2015-01-07  423.139069                     NaN       NaN             NaN
# ...                ...                     ...       ...             ...
# 2023-03-01         NaN                     NaN       NaN     2334.740162
# 2023-03-02         NaN                     NaN       NaN     2337.097485
# 2023-03-03         NaN                     NaN       NaN     2337.714232
# 2023-03-04         NaN                     NaN       NaN     2338.009710
# 2023-03-05         NaN                     NaN       NaN     2338.558757
#
# [2031 rows x 4 columns]

# %%
new_pred.drop(['Close First Difference','forecast'],axis=1,inplace=True)
new_pred
# Out:
#                  Close  predicted_mean
# 2015-01-01  439.781311             NaN
# 2015-01-02  438.617340             NaN
# 2015-01-05  433.812897             NaN
# 2015-01-06  414.124512             NaN
# 2015-01-07  423.139069             NaN
# ...                ...             ...
# 2023-03-01         NaN     2334.740162
# 2023-03-02         NaN     2337.097485
# 2023-03-03         NaN     2337.714232
# 2023-03-04         NaN     2338.009710
# 2023-03-05         NaN     2338.558757
#
# [2031 rows x 2 columns]

# %%
plt.figure(figsize=(30,15))
plt.plot(new_pred)
# Out:
# [<matplotlib.lines.Line2D at 0x23d810c5e20>,
#  <matplotlib.lines.Line2D at 0x23d810c5d60>]

# %%
plt.plot(new_pred[1958:2018])
# Out:
# [<matplotlib.lines.Line2D at 0x23d84182520>,
#  <matplotlib.lines.Line2D at 0x23d84182dc0>]
